# %%
byte01 = [34, 38, 44, 48,64, 82, 36,40,42,46,50,64,68,38,42,46,44,48,68,86,48,52,40,44,64,82,36,40,42,46,34,82,42,46,44,48,36,84,44,48,38,92,46,50,40,94,48,52,42,96]

# %%
byte01 = list(dict.fromkeys(byte01))

# %%
print(byte01)
# Out:
# [34, 38, 44, 48, 64, 82, 36, 40, 42, 46, 50, 68, 86, 52, 84, 92, 94, 96]

# %%
byte01.sort()
print(byte01)
# Out:
# [34, 36, 38, 40, 42, 44, 46, 48, 50, 52, 64, 68, 82, 84, 86, 92, 94, 96]

# %%
print(len(byte01))
# Out:
# 18

# %%
byte23 = [50,54,44,80,52,56,46,82,54,58,48,84,56,60,50,98,58,62,52,100,54,108,56,110,58,112,60,64,62,66,64,68,]
byte23 = list(dict.fromkeys(byte23))
byte23.sort()
print(byte23)
print(len(byte23))
# Out:
# [44, 46, 48, 50, 52, 54, 56, 58, 60, 62, 64, 66, 68, 80, 82, 84, 98, 100, 108, 110, 112]
# 21

# %%
byte45 = [66,70,60,96,68,72,88,100,104,120,62,98,70,74,90,102,106,122,67,100,66,76,82,102,114,130,68,78,84,104,116,132,38,70,76,80,108,112,86,106,118,134,40,82,88,108,120,136,42,84,90,110,122,138]
byte45 = list(dict.fromkeys(byte45))
byte45.sort()
print(byte45)
print(len(byte45))
# Out:
# [38, 40, 42, 60, 62, 66, 67, 68, 70, 72, 74, 76, 78, 80, 82, 84, 86, 88, 90, 96, 98, 100, 102, 104, 106, 108, 110, 112, 114, 116, 118, 120, 122, 130, 132, 134, 136, 138]
# 38

# %%
byte45 = [66, 68, 70, 72, 130, 132, 134, 136, 176, 178, 180, 182,28, 30, 32, 60, 62, 64, 76, 86, 88, 90, 92, 94, 96, 118, 120, 122, 124, 126, 128, 140, 144, 146, 148, 150, 152, 154, 180, 182, 184, 186, 188, 190, 192 ] 
byte45 = list(dict.fromkeys(byte45))
byte45.sort()
print(byte45)
print(len(byte45))
# Out:
# [28, 30, 32, 60, 62, 64, 66, 68, 70, 72, 76, 86, 88, 90, 92, 94, 96, 118, 120, 122, 124, 126, 128, 130, 132, 134, 136, 140, 144, 146, 148, 150, 152, 154, 176, 178, 180, 182, 184, 186, 188, 190, 192]
# 43

# %%
byte67 = [76,86,92,112,124,140,78,88,94,114,126,142,48,80,86,90,118,122,96,116,128,144,50,82,88,92,120,124,98,118,130,146,52,84,90,94,122,126,100,120,132,148,54,86,92,96,124,128,102,122,134,150,56,98,104,124,136,152,58,100,106,126,138,154]
byte67 = list(dict.fromkeys(byte67))
byte67.sort()
print(byte67)
print(len(byte67))
# Out:
# [48, 50, 52, 54, 56, 58, 76, 78, 80, 82, 84, 86, 88, 90, 92, 94, 96, 98, 100, 102, 104, 106, 112, 114, 116, 118, 120, 122, 124, 126, 128, 130, 132, 134, 136, 138, 140, 142, 144, 146, 148, 150, 152, 154]
# 44

# %%
byte89 = [60,92,98,102,130,128,140,156,62,94,100,104,132,136,110,130,142,158,64,96,102,106,134,138,112,132,144,160,34,124,82,98,114,130,134,152,36,126,84,100,116,132,136,154,38,128,86,102,40,130,88,104,120,136,140,158,42,132,90,106,122,138,142,160]
byte89 = list(dict.fromkeys(byte89))
byte89.sort()
print(byte89)
print(len(byte89))
# Out:
# [34, 36, 38, 40, 42, 60, 62, 64, 82, 84, 86, 88, 90, 92, 94, 96, 98, 100, 102, 104, 106, 110, 112, 114, 116, 120, 122, 124, 126, 128, 130, 132, 134, 136, 138, 140, 142, 144, 152, 154, 156, 158, 160]
# 43

# %%
byte1011 = [44, 102, 114, 118, 134, 146, 150, 166, 34, 66, 98, 108, 128, 140, 156, 162,  46, 82, 104, 116, 136, 148, 168, 36, 68, 100, 110, 130, 142, 158, 164,48, 84, 106, 118, 138, 150, 170,38, 70, 102, 112, 132, 144, 160, 166,50, 86, 108, 120, 140, 152, 172, 40, 72, 104, 114, 134, 146, 162, 168, 52, 88, 110, 122, 142, 154, 174,42, 74, 106, 116, 136, 148, 164, 170,54, 90, 112, 124, 144, 156, 176, 44, 76, 108, 118, 138, 150, 166, 172,56, 92, 114, 126, 146, 158, 178, 46, 78, 110, 120, 140, 152, 168, 174, 0, 58, 94, 116, 128, 148, 160, 180,48, 80, 112, 122, 142, 154, 170, 176]
byte1011 = list(dict.fromkeys(byte1011))
byte1011.sort()
print(byte1011)
print(len(byte1011))
# Out:
# [0, 34, 36, 38, 40, 42, 44, 46, 48, 50, 52, 54, 56, 58, 66, 68, 70, 72, 74, 76, 78, 80, 82, 84, 86, 88, 90, 92, 94, 98, 100, 102, 104, 106, 108, 110, 112, 114, 116, 118, 120, 122, 124, 126, 128, 130, 132, 134, 136, 138, 140, 142, 144, 146, 148, 150, 152, 154, 156, 158, 160, 162, 164, 166, 168, 170, 172, 174, 176, 178, 180]
# 71

# %%
byte1213 = [2, 34, 60, 66, 92, 96, 98, 118, 124, 154, 162, 182, 50, 114, 160,4, 36, 62, 68, 94, 98, 100, 120, 126, 156, 164, 184, 52, 116, 162, 6, 38, 64, 70, 96, 100, 102, 122, 128, 158, 166, 186, 54, 118, 164, 8, 40, 66, 72, 98, 102, 104, 124, 130, 160, 168, 188, 56, 120, 166, 10, 42, 68, 74, 100, 104, 106, 126, 132, 162, 170, 190, 58, 122, 168, 12, 44, 70, 76, 102, 106, 108, 128, 134, 164, 172, 192, 60, 124, 170, 14, 46, 72, 78, 104, 108, 110, 130, 136, 166, 174, 194, 62, 126, 172, 16, 48, 74, 80, 106, 110, 112, 132, 138, 168, 176, 196, 64, 128, 174]

byte1213 = list(dict.fromkeys(byte1213))
byte1213.sort()
print(byte1213)
print(len(byte1213))
# Out:
# [2, 4, 6, 8, 10, 12, 14, 16, 34, 36, 38, 40, 42, 44, 46, 48, 50, 52, 54, 56, 58, 60, 62, 64, 66, 68, 70, 72, 74, 76, 78, 80, 92, 94, 96, 98, 100, 102, 104, 106, 108, 110, 112, 114, 116, 118, 120, 122, 124, 126, 128, 130, 132, 134, 136, 138, 154, 156, 158, 160, 162, 164, 166, 168, 170, 172, 174, 176, 182, 184, 186, 188, 190, 192, 194, 196]
# 76

# %%
byte1415 = [18, 50, 76, 82, 108, 112, 114, 134, 140, 170, 178, 198,66, 130, 176,20, 52, 78, 84, 110, 114, 116, 136, 142, 172, 180, 200,68, 178,22, 54, 80, 86, 112, 116, 118, 138, 144, 174, 182, 202,70, 134, 180,24, 56, 82, 88, 114, 118, 120, 140, 146, 176, 184, 204,72, 136, 182,26, 58, 84, 90, 116, 120, 122, 142, 148, 178, 186, 206,74, 138, 184,28, 60, 86, 92, 118, 122, 124, 144, 150, 180, 188, 208,76, 140, 186,30, 62, 88, 94, 120, 124, 126, 146, 152, 182, 190, 210,78, 142, 188,32, 64, 90, 96, 122, 126, 128, 148, 154, 184, 192, 212,80, 144, 190]
byte1415 = list(dict.fromkeys(byte1415))
byte1415.sort()
print(byte1415)
print(len(byte1415))
# Out:
# [18, 20, 22, 24, 26, 28, 30, 32, 50, 52, 54, 56, 58, 60, 62, 64, 66, 68, 70, 72, 74, 76, 78, 80, 82, 84, 86, 88, 90, 92, 94, 96, 108, 110, 112, 114, 116, 118, 120, 122, 124, 126, 128, 130, 134, 136, 138, 140, 142, 144, 146, 148, 150, 152, 154, 170, 172, 174, 176, 178, 180, 182, 184, 186, 188, 190, 192, 198, 200, 202, 204, 206, 208, 210, 212]
# 75

# %%
byte1415 = [42,46,62,74,78,94, 36,68,72,84,90, 44,48,64,76,80,96, 38,70,74,86,92, 46,50,66,78,82,98, 40,72,76,88,94, 48,52,68,80,84, 100, 42,74,78,90,96]
byte1415 = list(dict.fromkeys(byte1415))
byte1415.sort()
print(byte1415)
print(len(byte1415))
# Out:
# [36, 38, 40, 42, 44, 46, 48, 50, 52, 62, 64, 66, 68, 70, 72, 74, 76, 78, 80, 82, 84, 86, 88, 90, 92, 94, 96, 98, 100]
# 29
